# %% [markdown]
# # SQL Interp Datasets Notebook

# %%
# %%capture
#!pip install git+https://github.com/gretelai/gretel-python-client@dev/data-designer-m1
# !pip install git+https://github.com/gretelai/gretel-python-client

session_kwargs = {
    "api_key": "prompt",
    "endpoint": "https://api-dev.gretel.cloud",
    "cache": "yes",
}

# %%
from gretel_client.navigator import DataDesigner
from datasets import Dataset
import yaml

# %% [markdown]
# ### 📘 Text-to-Python Blueprint

# %%
with open('cs11.yaml', 'r') as file:
    blueprint_string = file.read()

# %%
# Defines a new DataDesigner instance
designer = DataDesigner.from_config(blueprint_string, **session_kwargs)
designer
# Out:
# Found cached Gretel credentials
# Using endpoint https://api-dev.gretel.cloud
# Logged in as dhruv@gretel.ai ✅
# [05:03:26] [INFO] 🦜 Using apache-2.0 model suite
# DataDesigner(
#     categorical_seed_columns: ['topic', 'instruction_phrase']
#     generated_data_columns: ['table_name', 'column_name', 'column_data_type', 'sql_prompt', 'sql_context', 'sql']
#     validator: code:ansi
#     evaluator: text_to_sql
# )

# %% [markdown]
# ### 👀 Generating a dataset preview

# %%
preview = designer.generate_dataset_preview()
# Out:
# [05:03:26] [INFO] 🚀 Generating dataset preview
# [05:03:27] [INFO] 🦜 Step 1: Generate seed category values
# [05:03:29] [INFO] 🎲 Step 2: Sample data seeds
# [05:03:29] [INFO] 🦜 Step 3: Generate column from template >> generating table name
# [05:03:30] [INFO] 🦜 Step 4: Generate column from template >> generating column name
# [05:03:32] [INFO] 🦜 Step 5: Generate column from template >> generating column data type
# [05:03:33] [INFO] 🦜 Step 6: Generate column from template >> generating sql prompt
# [05:03:35] [INFO] 🦜 Step 7: Generate column from template >> generating sql context
# [05:03:36] [INFO] 🦜 Step 8: Generate column from template >> generating sql
# [05:03:38] [INFO] 🔍 Step 9: Validate code
# [05:03:40] [INFO] ⚖️ Step 10: Judge with llm
# [05:03:49] [INFO] 🧐 Step 11: Evaluate dataset
# [05:03:49] [INFO] 👀 Your dataset preview is ready for a peek!
# ----------------------------------------------------------------------------------------------------
#                                 📊 Preview Evaluation Summary 📊
# ----------------------------------------------------------------------------------------------------
#
#                                                                          LLM-as-a-Judge
#                 Quality & Diversity                        ┏━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓       ┃      Rubric ┃ Mean Score (0 - 5)       ┃
# ┃              Values ┃ Percent of Records         ┃       ┡━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩       │   Relevance │ ████████████████████ 4.0 │
# │          Valid Code │ ████████████████████ 100.0 │       │ Readability │ ███████████████ 3.0      │
# │   Completely Unique │ ████████████████████ 100.0 │       │ Scalability │ █████████████████ 3.4    │
# │ Semantically Unique │ ████████████████████ 100.0 │       │   Standards │ ████████████████████ 4.0 │
# └─────────────────────┴────────────────────────────┘       └─────────────┴──────────────────────────┘
#
#
#                                              Text Stats
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃             average_words_per_record ┃             average_tokens_per_record ┃      total_tokens ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │                                  2.6 │                                  59.7 │               597 │
# └──────────────────────────────────────┴───────────────────────────────────────┴───────────────────┘
#
# ----------------------------------------------------------------------------------------------------

# %%
preview.display_sample_record(index=5)
# Out:
#
#                                              Categorical Seed Columns
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Name                                                 ┃ Value                                                    ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ topic                                                │ orders                                                   │
# ├──────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────┤
# │ instruction_phrase                                   │ Create a summary for                                     │
# └──────────────────────────────────────────────────────┴──────────────────────────────────────────────────────────┘
#
#
#                                               Generated Data Columns
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Name                      ┃ Value                                                                               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ table_name                │ orders_table                                                                        │
# ├───────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────┤
# │ column_name               │ order_id                                                                            │
# ├───────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────┤
# │ column_data_type          │ INT                                                                                 │
# ├───────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────┤
# │ sql_prompt                │ Create a summary for the order_id from the orders_table                             │
# └───────────────────────────┴─────────────────────────────────────────────────────────────────────────────────────┘
#
#
# ╭────────────────────────────────────────────────── sql_context ──────────────────────────────────────────────────╮
# │ CREATE TABLE orders_table (                                                                                     │
# │     order_id INT                                                                                                │
# │ );                                                                                                              │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#
#
# ╭────────────────────────────────────────────────────── sql ──────────────────────────────────────────────────────╮
# │ SELECT order_id FROM orders_table;                                                                              │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#
#
#                                                     Validation
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ sql_context_is_valid      ┃ sql_context_validator_messages       ┃ sql_is_valid    ┃ sql_validator_messages     ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ True                      │ []                                   │ True            │ []                         │
# └───────────────────────────┴──────────────────────────────────────┴─────────────────┴────────────────────────────┘
#
#
#                                                   LLM-as-a-Judge
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ relevance                  ┃ readability               ┃ scalability                ┃ standards                 ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ score: 4                   │ score: 3                  │ score: 3                   │ score: 4                  │
# │ reasoning: The SQL query   │ reasoning: The query is   │ reasoning: The query is    │ reasoning: The query      │
# │ perfectly meets the        │ well-formatted and easy   │ simple and should scale    │ adheres strictly to SQL   │
# │ instructions and context,  │ to understand, but it     │ well, but it hasn't been   │ standards and follows     │
# │ retrieving order_id from   │ could benefit from a      │ tested with large          │ best practices for        │
# │ the orders_table.          │ comment explaining its    │ datasets.                  │ simplicity and clarity.   │
# │                            │ purpose.                  │                            │                           │
# └────────────────────────────┴───────────────────────────┴────────────────────────────┴───────────────────────────┘
#
#                                                     [index: 5]

# %%
preview.output
# Out:
#              topic           instruction_phrase                 table_name  \
# 0        customers          Compose a report on             customers_info
# 1  human_resources         Generate a chart for  human_resources_employees
# 2        inventory                 Retrieve the            inventory_items
# 3        customers         Create a summary for             customers_info
# 4        customers                  Extract the             customers_info
# 5           orders         Create a summary for               orders_table
# 6          finance                 Retrieve the               finance_data
# 7  human_resources  Develop a questionnaire for  human_resources_employees
# 8  human_resources            Draft a letter to  human_resources_employees
# 9        customers                  Provide the             customers_info
#
#          column_name column_data_type  \
# 0        customer_id              INT
# 1        employee_id              INT
# 2  inventory_item_id              INT
# 3        customer_id              INT
# 4        customer_id              INT
# 5           order_id              INT
# 6     finance_amount          DECIMAL
# 7        employee_id              INT
# 8        employee_id              INT
# 9       customers_id              INT
#
#                                           sql_prompt  \
# 0  Compose a report on customer_id from customers...
# 1  Generate a chart for employee_id from human_re...
# 2  Retrieve the inventory_item_id from the invent...
# 3  Create a summary for customer_id from customer...
# 4        Extract the customer_id from customers_info
# 5  Create a summary for the order_id from the ord...
# 6      Retrieve the finance_amount from finance_data
# 7  Develop a questionnaire for selecting employee...
# 8  Draft a letter to select employee_id from huma...
# 9       Provide the customers_id from customers_info
#
#                                          sql_context  \
# 0  CREATE TABLE customers_info (\n    customer_id...
# 1  CREATE TABLE human_resources_employees (\n    ...
# 2  CREATE TABLE inventory_items (\n    inventory_...
# 3  CREATE TABLE customers_info (\n    customer_id...
# 4  CREATE TABLE customers_info (\n    customer_id...
# 5  CREATE TABLE orders_table (\n    order_id INT\n);
# 6  CREATE TABLE finance_data (\n    finance_amoun...
# 7  CREATE TABLE human_resources_employees (\n    ...
# 8  CREATE TABLE human_resources_employees (\n    ...
# 9  CREATE TABLE customers_info (\n    customers_i...
#
#                                                  sql  sql_context_is_valid  \
# 0            SELECT customer_id FROM customers_info;                  True
# 1  SELECT employee_id FROM human_resources_employ...                  True
# 2     SELECT inventory_item_id FROM inventory_items;                  True
# 3            SELECT customer_id FROM customers_info;                  True
# 4            SELECT customer_id FROM customers_info;                  True
# 5                 SELECT order_id FROM orders_table;                  True
# 6           SELECT finance_amount FROM finance_data;                  True
# 7  SELECT employee_id FROM human_resources_employ...                  True
# 8  SELECT employee_id FROM human_resources_employ...                  True
# 9           SELECT customers_id FROM customers_info;                  True
#
#   sql_context_validator_messages  sql_is_valid sql_validator_messages  \
# 0                             []          True                     []
# 1                             []          True                     []
# 2                             []          True                     []
# 3                             []          True                     []
# 4                             []          True                     []
# 5                             []          True                     []
# 6                             []          True                     []
# 7                             []          True                     []
# 8                             []          True                     []
# 9                             []          True                     []
#
#    judged_by_llm                      text_to_sql_llm_judge_results
# 0           True  {'relevance': {'score': 4, 'reasoning': 'The S...
# 1           True  {'relevance': {'score': 4, 'reasoning': 'The S...
# 2           True  {'relevance': {'score': 4, 'reasoning': 'The S...
# 3           True  {'relevance': {'score': 4, 'reasoning': 'The S...
# 4           True  {'relevance': {'score': 4, 'reasoning': 'The S...
# 5           True  {'relevance': {'score': 4, 'reasoning': 'The S...
# 6           True  {'relevance': {'score': 4, 'reasoning': 'The S...
# 7           True  {'relevance': {'score': 4, 'reasoning': 'The S...
# 8           True  {'relevance': {'score': 4, 'reasoning': 'The S...
# 9           True  {'relevance': {'score': 4, 'reasoning': 'The S...

# %%
dataset_preview = Dataset.from_pandas(preview.output)
dataset_preview.push_to_hub(f"dhruvnathawani/cs11-preview")

# %% [markdown]
# ### 🤔 Like what you see? Generate an entire dataset

# %%
# Submit a batch workflow to generate records
results = designer.submit_batch_workflow(num_records=500)
# Out:
# [05:03:50] [INFO] ⚙️ Configuring Data Designer Workflow steps:
# [05:03:50] [INFO]   |-- Step 1: generate-seed-category-values-1
# [05:03:50] [INFO]   |-- Step 2: sample-data-seeds-2
# [05:03:50] [INFO]   |-- Step 3: generate-column-from-template-3-generating-table-name
# [05:03:50] [INFO]   |-- Step 4: generate-column-from-template-4-generating-column-name
# [05:03:50] [INFO]   |-- Step 5: generate-column-from-template-5-generating-column-data-type
# [05:03:50] [INFO]   |-- Step 6: generate-column-from-template-6-generating-sql-prompt
# [05:03:50] [INFO]   |-- Step 7: generate-column-from-template-7-generating-sql-context
# [05:03:50] [INFO]   |-- Step 8: generate-column-from-template-8-generating-sql
# [05:03:50] [INFO]   |-- Step 9: validate-code-9
# [05:03:50] [INFO]   |-- Step 10: judge-with-llm-10
# [05:03:50] [INFO]   |-- Step 11: evaluate-dataset-11
# [05:03:57] [INFO] 🛜 Connecting to your Gretel Project:
# [05:03:57] [INFO] 🔗 -> https://console-dev.gretel.ai/proj_2pmd98MaNUS0rUw8YRNWlJdxJoJ
# [05:04:00] [INFO] ▶️ Starting your workflow run to generate 500 records:
# [05:04:00] [INFO]   |-- project_name: gretel-sdk-7e625-a4f565a4c39a7e0
# [05:04:00] [INFO]   |-- project_id: proj_2pmd98MaNUS0rUw8YRNWlJdxJoJ
# [05:04:00] [INFO]   |-- workflow_run_id: wr_2pmdAU7FdddgASkUH6MloOb5sBm
# [05:04:00] [INFO] 🔗 -> https://console-dev.gretel.ai/workflows/w_2pmdAE4QGugstI4JpldG1Ouqe6Z/runs/wr_2pmdAU7FdddgASkUH6MloOb5sBm

# %%
# Fetch the dataset
df = results.fetch_dataset(wait_for_completion=True)
# Out:
# [05:04:06] [INFO] ⏳ Waiting for workflow step `judge-with-llm-10` to complete...
# [05:04:06] [INFO] 👀 Follow along -> https://console-dev.gretel.ai/workflows/w_2pmdAE4QGugstI4JpldG1Ouqe6Z/runs/wr_2pmdAU7FdddgASkUH6MloOb5sBm

# %%
path = results.download_evaluation_report()

# %%
print(df.keys())
